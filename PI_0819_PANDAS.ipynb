# %% [markdown]
# <a href="https://colab.research.google.com/github/ana-clara-souza/machine-learning/blob/main/PI_0819_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introdução ao Pandas

# %% [markdown]
# ##NumPy
# - Rápida
# - Trabalha apenas com dados numericos
# - 100% em C
# - Armazenamento de dados na memória (melhor opção)
#
# ##Pandas
# - Feito em cima do NumPy
# - Armazena dados heterogeneos
# - Várias colunas e linhas
# - Estrutura interna:
# - - Series (coluna do dataframe)
# - - DataFrame (conjunbto todo)

# %%
# !pip install pandas #instalação

# %%
#Criar meu primeiro dataframe

#Forma mais fácil: construir a partir de outra estrtura de dadoos, ex: dicionário

produtos = {
    "codigo":[101, 102, 103, 104],
    "nome":["Monitor", "Celular", "Teclado", "Mouse"],
    "preco":[800.00, 5000.00, 200, 100.00],
    "estoque":[5, 4, 10, 15]
}

# %%
produtos.keys()
produtos.values()
# Out:
# dict_values([[101, 102, 103, 104], ['Monitor', 'Celular', 'Teclado', 'Mouse'], [800.0, 5000.0, 200, 100.0], [5, 4, 10, 15]])

# %%
import pandas as pd

# %%
#Gerar dataframe
df = pd.DataFrame(produtos) #quando chama devolve um objeto, df armazena ele

# %%
df #visualização
#Chave - coluna
#Valores - linhas
# Out:
#    codigo     nome   preco  estoque
# 0     101  Monitor   800.0        5
# 1     102  Celular  5000.0        4
# 2     103  Teclado   200.0       10
# 3     104    Mouse   100.0       15

# %%
#Propriedades
df.info()

#mostra os detalhes do dataframe
#mostra os dados faltantes
#tipo de dados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   codigo   4 non-null      int64
#  1   nome     4 non-null      object
#  2   preco    4 non-null      float64
#  3   estoque  4 non-null      int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 260.0+ bytes

# %%
df.shape #mostra a dimensão
# Out:
# (4, 4)

# %%
# Incluir nova coluna
#Total estoque ($) - baseada em preço

df['total Estoque'] = df['estoque'] * df['preco']

# %%
df
# Out:
#    codigo     nome   preco  estoque  total Estoque
# 0     101  Monitor   800.0        5         4000.0
# 1     102  Celular  5000.0        4        20000.0
# 2     103  Teclado   200.0       10         2000.0
# 3     104    Mouse   100.0       15         1500.0

# %%
df['total Estoque'].mean() #valor médio de custo da coluna
# Out:
# np.float64(6875.0)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #Biblioteca Kaggle
#
# O Kaggle é a maior plataforma online do mundo para ciência de dados e aprendizado de máquina (machine learning), pertencente ao Google. Ela reúne milhões de usuários para compartilhar dados, criar códigos na nuvem, participar de competições com prêmios em dinheiro e aprender novas técnicas de inteligência artificial

# %% [markdown]
# ### Estudo de caso: Airline Passenger Satisfaction
# (https://www.kaggle.com/datasets/teejmahal20/airline-passenger-satisfaction)

# %%
df = pd.read_csv("train.csv.zip", compression="zip") #leitor de csv e se estiver compactado ele descompacta

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df

# %%
df.info()

# %%
df.isna().sum() #corre todas as colunas e soma os dados faltantes

# %% [markdown]
# # Exercícios práticos

# %%
# #Estrtura inicial
# import pandas as pd
# produtos = {
#     "codigo":[1, 2, 3],
#     "nome":["teclado", "mouse", "caneta"],
#     "valores":[200, 100, 5],
#     "estoque":[10, 2, 50]
# }

# df = pd.DataFrame(produtos)

# %%
# df

# %%
#1. Inspeção das Dimensões

# df.shape

# %%
#Informações e Tipos de Dados
# df.info()

# %%
#3. Nova Coluna Calculada

# df['faturamento_potencial'] = df['valores']*df['estoque']

# %%
#4. Estatística da Nova Coluna

# df['faturamento_potencial'].mean().sum()

# %%
#5. Filtragem Simples de Registros

# df[df['valores']>5]

# %% [markdown]
# **Diferença Básica: .iloc vs .loc.iloc: **
#  Usa posições numéricas inteiras (0, 1, 2...). Ignora o nome dos índices..loc: Usa os rótulos ou nomes reais das linhas e colunas.

# %%
#6. Seleção por Posição (iloc)
#df.iloc[linhas, colunas]

# df.iloc[0] #retorna a primeria linha
# df.iloc[0:3] #retorna da primeria ate terceira linha
# df.iloc[0:2, 0:2] #seleciona as duas primeiras linhas e as duas primeiras colunas

# %% [markdown]
# #AULA 24/08

# %%
df.describe()

# %%
#remoção de colunas irrelevantes
# Unnamed:0
# remove as colunas chamadas 'Unnamed: 0' e 'id'
df = df.drop(columns=['Unnamed: 0', 'id'])

# %%
df

# %%
#substituir dados faltantes

media_atrasos = df['Arrival Delay in Minutes'].mean()
print(f"Média: {media_atrasos}")

# %%
#preencher os dadfos faltantes pela média
#fillna -- roda o dataframe na coluna in dicada verificando todos os valores NaN e trocando pelo valor indicado
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(media_atrasos)

# %%
df

# %%
df['Arrival Delay in Minutes'].mean()

# %%
#precisa preencher os NaN por conta dos algoritmos de aprendizado de máquina, para de reduzir as chnaces de retornar erro

# %% [markdown]
# #investigando a base de dados

# %%
df.columns

# %%
#pesquisa na abse de dados
#df.loc - permite colocar o nome das colunas
#df.iloc(linha, coluna) --- utilizando o indice


df.loc[100:120, ['Gender', 'Customer Type', 'Age']]

# %%
#valores das colunas categoricas
#colunas categoricas - são colunas com string

#descobrir colunas não númericas

cat_cols = df.select_dtypes(include='object').columns.tolist() #include é quais sao os dtypes que quero extrair, escolhe as colunas, transforma em uma lista tolist
print(cat_cols)

# %%
#valores das colunas numericas

num_cols = df.select_dtypes(include=['int64','float64']).columns.tolist()

# %%
for col in cat_cols:
  print(f"{col} - {df[col].unique()}") #dados únicos da categoria

# %%
# Filtro
#Operadores booleanos
# & (E)
# | (OU)
# ~ (NÃO)
filtro = ((df['Type of Travel']== 'Business travel') & #tipo de viagem business travel
          (df['Class']=='Eco') &
          (df['Flight Distance']>1500)

)

# %%
filtro

# %%
#aplicar o filtro booleano

dados_filtrados = df.loc[filtro, ['Age', 'Gender', 'Customer Type', 'satisfaction']]

# %%
dados_filtrados

# %%
len(df)
